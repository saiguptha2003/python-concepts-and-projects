# %% [markdown]
# # Union Budget (2022-23) - Direct Taxes Analysis
#
# ### Imformation regarding Direct Taxes :
# Total Union Budget allocation for the collection of direct taxes under the Ministry of Finance. It contains budgetray allocations by the Union Government for requirement of Income-Tax Department, which administers all direct taxes levied and collected by the Central Government, namely, taxes on income (including income of the corporate sector), wealth tax, securities transaction tax.

# %% [markdown]
# #### Importing usefull libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# #### creating a analysitic_data using pandas and accessing csv file

# %%
analysitic_data=pd.read_csv("direct-taxes.csv")

# %% [markdown]
# #### display dataset as analysitic_data

# %%
analysitic_data
# Out:
#     Index                                        Particulars        Type  \
# 0     NaN                                                NaN       Gross
# 1     NaN                                                NaN  Recoveries
# 2     NaN                                                NaN    Receipts
# 3     NaN                                                NaN         Net
# 4     NaN  A. The Budget allocations, net of recoveries, ...         NaN
# 5     NaN                               CENTRE'S EXPENDITURE         NaN
# 6     NaN            Establishment Expenditure of the Centre         NaN
# 7       1      Collection of Taxes on Income and Expenditure         NaN
# 8    1.01                           Collection of Income Tax         NaN
# 9    1.02                      Collection of Corporation Tax         NaN
# 10   1.03                                  Actual Recoveries         NaN
# 11    NaN                                                NaN         Net
# ...

# %% [markdown]
# #### Display bottom records in the analysitic_data

# %%
analysitic_data.tail()
# Out:
#     Index                                        Particulars Type  \
# 41  2.02.  Securities Transaction Tax:..This includes pro...  NaN
# 42  2.03.  Collection of Other Taxes:..This includes prov...  NaN
# 43  2.04.  Purchase of Ready Built Accommodation - Office...  NaN
# 44  2.05.  Purchase of Ready Built Accommodation - Reside...  NaN
# 45      3  Acquisition of Immovable Property under the In...  NaN
#
#    Actual 2020-2021 Revenue Actual 2020-2021 Capital Actual 2020-2021 Total  \
# 41                      NaN                      NaN                    NaN
# 42                      NaN                      NaN                    NaN
# 43                      NaN                      NaN                    NaN
# 44                      NaN                      NaN                    NaN
# 45                      NaN                      NaN                    NaN
#
#    Budget 2021-2022 Revenue Budget 2021-2022 Capital Budget 2021-2022 Total  \
# ...

# %% [markdown]
# #### Displaying top 5 records or rows in the analysitic_data

# %%
analysitic_data.head()
# Out:
#   Index                                        Particulars        Type  \
# 0   NaN                                                NaN       Gross
# 1   NaN                                                NaN  Recoveries
# 2   NaN                                                NaN    Receipts
# 3   NaN                                                NaN         Net
# 4   NaN  A. The Budget allocations, net of recoveries, ...         NaN
#
#   Actual 2020-2021 Revenue Actual 2020-2021 Capital Actual 2020-2021 Total  \
# 0                  7229.93                   173.14                7403.07
# 1                    -6.64                    -0.05                  -6.69
# 2                      ...                      ...                    ...
# 3                  7223.29                   173.09                7396.38
# 4                      NaN                      NaN                    NaN
#
#   Budget 2021-2022 Revenue Budget 2021-2022 Capital Budget 2021-2022 Total  \
# ...

# %% [markdown]
# #### Display the rows and columns count

# %%
analysitic_data.shape
# Out:
# (46, 15)

# %% [markdown]
# #### Display the size of the data frame

# %%
analysitic_data.size
# Out:
# 690

# %% [markdown]
# #### Display all columns in the data frame

# %%
analysitic_data.columns
# Out:
# Index(['Index', 'Particulars', 'Type', 'Actual 2020-2021 Revenue',
#        'Actual 2020-2021 Capital', 'Actual 2020-2021 Total',
#        'Budget 2021-2022 Revenue', 'Budget 2021-2022 Capital',
#        'Budget 2021-2022 Total', 'Revised 2021-2022 Revenue',
#        'Revised 2021-2022 Capital', 'Revised 2021-2022 Total',
#        'Budget 2022-2023 Revenue', 'Budget 2022-2023 Capital',
#        'Budget 2022-2023 Total'],
#       dtype='object')

# %%
analysitic_data.dtypes
# Out:
# Index                        object
# Particulars                  object
# Type                         object
# Actual 2020-2021 Revenue     object
# Actual 2020-2021 Capital     object
# Actual 2020-2021 Total       object
# Budget 2021-2022 Revenue     object
# Budget 2021-2022 Capital     object
# Budget 2021-2022 Total       object
# Revised 2021-2022 Revenue    object
# Revised 2021-2022 Capital    object
# Revised 2021-2022 Total      object
# Budget 2022-2023 Revenue     object
# Budget 2022-2023 Capital     object
# Budget 2022-2023 Total       object
# dtype: object

# %% [markdown]
# #### Information regarding the dataframe

# %%
analysitic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Index                      26 non-null     object
#  1   Particulars                40 non-null     object
#  2   Type                       6 non-null      object
#  3   Actual 2020-2021 Revenue   27 non-null     object
#  4   Actual 2020-2021 Capital   27 non-null     object
#  5   Actual 2020-2021 Total     27 non-null     object
#  6   Budget 2021-2022 Revenue   27 non-null     object
#  7   Budget 2021-2022 Capital   27 non-null     object
#  8   Budget 2021-2022 Total     27 non-null     object
#  9   Revised 2021-2022 Revenue  27 non-null     object
#  10  Revised 2021-2022 Capital  27 non-null     object
#  11  Revised 2021-2022 Total    27 non-null     object
#  12  Budget 2022-2023 Revenue   27 non-null     object
# ...

# %% [markdown]
# ## Cleaning Data using tools

# %% [markdown]
# #### Grouping the dulicate rows in the dataframe

# %%
analysitic_data[analysitic_data.duplicated()]
# Out:
#    Index  Particulars Type Actual 2020-2021 Revenue Actual 2020-2021 Capital  \
# 37   NaN  Grand Total  NaN                  7223.29                   173.09
#
#    Actual 2020-2021 Total Budget 2021-2022 Revenue Budget 2021-2022 Capital  \
# 37                7396.38                  8180.34                      350
#
#    Budget 2021-2022 Total Revised 2021-2022 Revenue Revised 2021-2022 Capital  \
# 37                8530.34                   8206.89                       300
#
#    Revised 2021-2022 Total Budget 2022-2023 Revenue Budget 2022-2023 Capital  \
# 37                 8506.89                   8866.8                      440
#
#    Budget 2022-2023 Total
# 37                 9306.8

# %% [markdown]
# #### removing the duplicates first known first remove

# %%
analysitic_data.drop_duplicates(inplace=True)

# %% [markdown]
# #### display which cell is is null not containing numbers

# %%
analysitic_data.isnull()
# Out:
#     Index  Particulars   Type  Actual 2020-2021 Revenue  \
# 0    True         True  False                     False
# 1    True         True  False                     False
# 2    True         True  False                     False
# 3    True         True  False                     False
# 4    True        False   True                      True
# 5    True        False   True                      True
# 6    True        False   True                      True
# 7   False        False   True                      True
# 8   False        False   True                     False
# 9   False        False   True                     False
# 10  False        False   True                     False
# 11   True         True  False                     False
# 12  False        False   True                      True
# 13  False        False   True                     False
# 14  False        False   True                     False
# 15  False        False   True                     False
# ...

# %% [markdown]
# #### replace all numpy.np and "..." to 0 numeric for the easy data extraction

# %%
analysitic_data = analysitic_data.fillna(0)
analysitic_data=analysitic_data.replace("...",0)
analysitic_data
# Out:
#     Index                                        Particulars        Type  \
# 0       0                                                  0       Gross
# 1       0                                                  0  Recoveries
# 2       0                                                  0    Receipts
# 3       0                                                  0         Net
# 4       0  A. The Budget allocations, net of recoveries, ...           0
# 5       0                               CENTRE'S EXPENDITURE           0
# 6       0            Establishment Expenditure of the Centre           0
# 7       1      Collection of Taxes on Income and Expenditure           0
# 8    1.01                           Collection of Income Tax           0
# 9    1.02                      Collection of Corporation Tax           0
# 10   1.03                                  Actual Recoveries           0
# 11      0                                                  0         Net
# ...

# %% [markdown]
# #### Calculating all null values in the data frame to get accurate values

# %%
analysitic_data.isnull().sum()
# Out:
# Index                        0
# Particulars                  0
# Type                         0
# Actual 2020-2021 Revenue     0
# Actual 2020-2021 Capital     0
# Actual 2020-2021 Total       0
# Budget 2021-2022 Revenue     0
# Budget 2021-2022 Capital     0
# Budget 2021-2022 Total       0
# Revised 2021-2022 Revenue    0
# Revised 2021-2022 Capital    0
# Revised 2021-2022 Total      0
# Budget 2022-2023 Revenue     0
# Budget 2022-2023 Capital     0
# Budget 2022-2023 Total       0
# dtype: int64

# %% [markdown]
# #### Heat map of null values of the taken dataset

# %%
plt.figure(figsize=(15,5))
sb.heatmap(data=analysitic_data.isnull())
plt.title("Null Values Of the department-of-expenditure.csv DataSet")
# Out:
# Text(0.5, 1.0, 'Null Values Of the department-of-expenditure.csv DataSet')

# %% [markdown]
# #### Change all cells to numeric values

# %%
l=analysitic_data.columns
for i in range(3,len(analysitic_data.columns)):
    analysitic_data[l[i]] = pd.to_numeric(analysitic_data[l[i]], errors = 'raise')
analysitic_data
# Out:
#     Index                                        Particulars        Type  \
# 0       0                                                  0       Gross
# 1       0                                                  0  Recoveries
# 2       0                                                  0    Receipts
# 3       0                                                  0         Net
# 4       0  A. The Budget allocations, net of recoveries, ...           0
# 5       0                               CENTRE'S EXPENDITURE           0
# 6       0            Establishment Expenditure of the Centre           0
# 7       1      Collection of Taxes on Income and Expenditure           0
# 8    1.01                           Collection of Income Tax           0
# 9    1.02                      Collection of Corporation Tax           0
# 10   1.03                                  Actual Recoveries           0
# 11      0                                                  0         Net
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ##### Q.1.finding the 'Grand Total' of all the years credit and debit revenue, what is the revenue, capital,toal?

# %%
analysitic_data[analysitic_data['Particulars'].isin(["Grand Total"])]
# Out:
#    Index  Particulars Type  Actual 2020-2021 Revenue  \
# 26     0  Grand Total    0                   7223.29
#
#     Actual 2020-2021 Capital  Actual 2020-2021 Total  \
# 26                    173.09                 7396.38
#
#     Budget 2021-2022 Revenue  Budget 2021-2022 Capital  \
# 26                   8180.34                     350.0
#
#     Budget 2021-2022 Total  Revised 2021-2022 Revenue  \
# 26                 8530.34                    8206.89
#
#     Revised 2021-2022 Capital  Revised 2021-2022 Total  \
# 26                        300                  8506.89
#
#     Budget 2022-2023 Revenue  Budget 2022-2023 Capital  Budget 2022-2023 Total
# 26                    8866.8                       440                  9306.8

# %% [markdown]
# ##### Q.2.Display all the particulars in the datasets ?

# %%
analysitic_data['Particulars']
# Out:
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4     A. The Budget allocations, net of recoveries, ...
# 5                                  CENTRE'S EXPENDITURE
# 6               Establishment Expenditure of the Centre
# 7         Collection of Taxes on Income and Expenditure
# 8                              Collection of Income Tax
# 9                         Collection of Corporation Tax
# 10                                    Actual Recoveries
# 11                                                    0
# 12    Collection of Taxes on Wealth, Securities Tran...
# 13                             Collection of Wealth Tax
# 14                           Securities Transaction Tax
# 15                            Collection of Other Taxes
# 16    Purchase of Ready Built Accommodation - Office...
# ...

# %% [markdown]
# ##### Q.3.Find the Secretariat General Services anual budget of 2023?

# %%
print(" Collection of Wealth Tax in anual budget of 2023  :",analysitic_data.loc[13]['Budget 2022-2023 Total'])
# Out:
#  Collection of Wealth Tax in anual budget of 2023  : 22.17

# %% [markdown]
# ##### Q.4.Find average budget of india of the given three years of Capital and  total?

# %%
sum=0
c=0

# %%
for i in analysitic_data.columns:
    if("Capital" in i and "Budget" in i):
        c=c+1
        tt=analysitic_data.loc[15][i]
        if(type(tt)==str):
            tt=float(tt)
        print(i,tt,sep="=")
        sum=tt+sum
print("Average budget of direct taxes of Capital in anual 2021-2022 and 2022-2023 peroid is ",sum//c)
# Out:
# Budget 2021-2022 Capital=0.0
# Budget 2022-2023 Capital=0
# Average budget of direct taxes of Capital in anual 2021-2022 and 2022-2023 peroid is  0.0

# %%
sum=0
c=0

# %%
for i in analysitic_data.columns:
    if("Total" in i and "Budget" in i):
        c=c+1
        tt=analysitic_data.loc[15][i]
        if(type(tt)==str):
            tt=float(tt)
        print(i,tt,sep="=")
        sum=tt+sum
print("Average budget of direct taxes of total budget in anual 2021-2022 and 2022-2023 peroid is ",sum//c)
# Out:
# Budget 2021-2022 Total=143.16
# Budget 2022-2023 Total=155.17
# Average budget of direct taxes of total budget in anual 2021-2022 and 2022-2023 peroid is  149.0

# %% [markdown]
# ##### Q.5.Generate a Graph to display all the parameters of the indexies in the given datasets budget analysis in the bar graphs for the clear visualization

# %%
analysitic_data.plot(kind="bar",x="Particulars",y=["Budget 2021-2022 Total","Revised 2021-2022 Total","Budget 2022-2023 Total"])
# Out:
# <Axes: xlabel='Particulars'>

# %% [markdown]
# ###### Q.7.Show difference between  budget of 2021-2022 and 2022-2023?

# %%
_df = analysitic_data
_df.plot.barh()
# Out:
# <Axes: >

# %% [markdown]
# ##### Q.8.find the maximum budgets in the given datasets?

# %%
analysitic_data.max()
# Out:
# C:\Users\pandu\AppData\Local\Temp\ipykernel_16516\2778987293.py:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   analysitic_data.max()
# Actual 2020-2021 Revenue     7229.93
# Actual 2020-2021 Capital      173.14
# Actual 2020-2021 Total       7403.07
# Budget 2021-2022 Revenue     8180.34
# Budget 2021-2022 Capital      352.00
# Budget 2021-2022 Total       8532.34
# Revised 2021-2022 Revenue    8206.89
# Revised 2021-2022 Capital     302.00
# Revised 2021-2022 Total      8508.89
# Budget 2022-2023 Revenue     8866.80
# Budget 2022-2023 Capital      442.00
# Budget 2022-2023 Total       9308.80
# dtype: float64

# %% [markdown]
# ##### Q.9.Find the difference between actual budget and revised budget of 2022-2023 peroid?

# %%
difference=analysitic_data['Budget 2021-2022 Revenue']-analysitic_data['Revised 2021-2022 Revenue']
j=0
t=analysitic_data["Particulars"].tolist()
for i in difference:
    print(t[j],i,sep="=")
    j=j+1
# Out:
# 0=-26.549999999999272
# 0=0.0
# 0=0.0
# 0=-26.549999999999272
# A. The Budget allocations, net of recoveries, are given below:=0.0
# CENTRE'S EXPENDITURE=0.0
# Establishment Expenditure of the Centre=0.0
# Collection of Taxes on Income and Expenditure=0.0
# Collection of Income Tax=-22.42999999999938
# Collection of Corporation Tax=-3.4600000000000364
# Actual Recoveries=0.0
# 0=-25.890000000000327
# Collection of Taxes on Wealth, Securities Transaction and other Taxes=0.0
# Collection of Wealth Tax=-0.07000000000000028
# Securities Transaction Tax=-0.13000000000000256
# Collection of Other Taxes=-0.46000000000000796
# Purchase of Ready Built Accommodation - Office Buildings=0.0
# Purchase of Ready Built Accommodation - Residential Buildings=0.0
# Total- Collection of Taxes on Wealth, Securities Transaction and other Taxes=-0.6599999999999966
# Total-Establishment Expenditure of the Centre=-26.549999999999272
# Other Central Sector Expenditure=0.0
# Others=0.0
# ...

# %% [markdown]
# ##### Q.10.Show how much  ranges  of expendutre and revenue Budget of 2022-2023 revenue budget?

# %%
analysitic_data.plot(kind='bar',x='Particulars', y='Budget 2022-2023 Revenue')
# Out:
# <Axes: xlabel='Particulars'>

# %% [markdown]
# #### show the co relation between  Budget 2022-2023 Total and Budget 2021-2022 Total?

# %%
analysitic_data.plot(kind="bar",x="Particulars",y=["Budget 2022-2023 Total","Budget 2021-2022 Total"])
# Out:
# <Axes: xlabel='Particulars'>

# %% [markdown]
# #### find the average total budget of given years?

# %%
total=analysitic_data['Budget 2022-2023 Total'][0]+analysitic_data['Budget 2021-2022 Total'][0]
print('average of two total budgets',total//2)
# Out:
# average of two total budgets 8920.0

# %% [markdown]
# ##### find the median of all columns?

# %%
analysitic_data.median()
# Out:
# C:\Users\pandu\AppData\Local\Temp\ipykernel_16516\3115023156.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   analysitic_data.median()
# Actual 2020-2021 Revenue     0.0
# Actual 2020-2021 Capital     0.0
# Actual 2020-2021 Total       0.0
# Budget 2021-2022 Revenue     0.0
# Budget 2021-2022 Capital     0.0
# Budget 2021-2022 Total       0.0
# Revised 2021-2022 Revenue    0.0
# Revised 2021-2022 Capital    0.0
# Revised 2021-2022 Total      0.0
# Budget 2022-2023 Revenue     0.0
# Budget 2022-2023 Capital     0.0
# Budget 2022-2023 Total       0.0
# dtype: float64

# %% [markdown]
# ##### find the mode of the given dataset?

# %%
analysitic_data.mode()
# Out:
#   Index Particulars Type  Actual 2020-2021 Revenue  Actual 2020-2021 Capital  \
# 0     0           0    0                       0.0                       0.0
#
#    Actual 2020-2021 Total  Budget 2021-2022 Revenue  Budget 2021-2022 Capital  \
# 0                     0.0                       0.0                       0.0
#
#    Budget 2021-2022 Total  Revised 2021-2022 Revenue  \
# 0                     0.0                        0.0
#
#    Revised 2021-2022 Capital  Revised 2021-2022 Total  \
# 0                          0                      0.0
#
#    Budget 2022-2023 Revenue  Budget 2022-2023 Capital  Budget 2022-2023 Total
# 0                       0.0                         0                     0.0

# %%
# Out:
# C:\Users\pandu\AppData\Local\Temp\ipykernel_16516\2280334959.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   analysitic_data.groupby(['Budget 2021-2022 Total']).sum().plot(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 analysitic_data.groupby(['Budget 2021-2022 Total']).sum().plot(
#       2     kind='pie', y='Budget 2022-2023 Total', autopct='%1.0f%%')
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# ...

# %% [markdown]
# ##### Exploratory Data Analysis Tests Ends

# %% [markdown]
# ## CONCLUSION:

# %% [markdown]
# 1.Collection of Wealth Tax in anual budget of 2023  : 22.17
# 2.Budget 2021-2022 Total=143.16
# 3.Budget 2022-2023 Total=155.17
# 4.Average budget of direct taxes of total budget in anual 2021-2022 and 2022-2023 peroid is  149.0
# 5.Budget 2021-2022 Capital=0.0
# 6.Budget 2022-2023 Capital=0
# 7.Average budget of direct taxes of Capital in anual 2021-2022 and 2022-2023 peroid is  0.0
# 8.The government proposes to spend Rs 39,44,909 crore in 2022-23, which is an increase of 4.6% over the revised estimate of 2021 22.In 2021-22, total expenditure is estimated to be 8.2% higher than budget estimate.
# 9.There is no change in income tax rates for individuals and corporations.
